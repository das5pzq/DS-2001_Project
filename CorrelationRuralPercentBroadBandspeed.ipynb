# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns 

data = pd.read_csv('Data.csv')

data_broadband = data.dropna(subset = ['Country','Broadband Speed Rank','Broadband Mbps'])
data_mobile = data.dropna(subset = ['Country','Mobile Speed Rank','Mobile Mbps'])

data_broadband.to_csv('Broadband.csv')
data_mobile.to_csv('Mobile.csv')

# data_rural = pd.read_csv('rural_pop_percent.csv')
# data_rural_pop = data_rural.loc[:,['Country Name','Percent']].dropna()
# data_rural_pop.to_csv("Rural Percentages.csv")
### Data Cleaning, 'Rural Percetentage.csv already made'
data_broadband_speed = data.loc[:,['Country','Broadband Mbps']].dropna()
data_broadband_speed.sort_values(by=['Country'], ascending=True)
data_broadband_speed.to_csv("Broadband Speed.csv")

broadBandSpeed = pd.read_csv('Broadband Speed.csv')
ruralPercent = pd.read_csv('Rural Percentages.csv')

sns.set_theme(color_codes = True)

#sns.regplot(x = cor['Rural Population'], y=cor['Broadband Mbps'], data = cor)
cor = pd.read_csv('cor1.csv')

cor.dropna()
#cor.plot(kind = 'scatter', x = 'Rural Population', y = 'Broadband Mbps')
#plt.show()
sns.set_theme(color_codes = True)

sns.regplot(x = cor['Rural Population'], y=cor['Broadband Mbps'], data = cor)
# Out:
# <AxesSubplot:xlabel='Rural Population', ylabel='Broadband Mbps'>

# %%
cor = pd.read_csv('cor1.csv')
#https://datahub.io/core/gdp
def convert(x):
    return x/(10**12)
cor.dropna()
cor['GDP 2020'] = cor['GDP 2020'].apply(convert)
cor.plot(kind = 'scatter',x='GDP 2020',y='Broadband Mbps')
sns.regplot(x=cor['GDP 2020'],y=cor['Broadband Mbps'], data=cor)
plt.savefig('GDP_Correlation.jpeg')
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
