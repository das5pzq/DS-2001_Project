# %%
import pandas as pd
import numpy as np
import plotly
import plotly.graph_objects as go
data = pd.read_csv(r'C:\Users\xXDRP\DS_2001\DS_2001_Project\DS-2001_Project\Data.csv')

data_broadband = data.dropna(subset = ['Country','Broadband Speed Rank','Broadband Mbps'])
data_mobile = data.dropna(subset = ['Country','Mobile Speed Rank','Mobile Mbps'])

data_broadband.to_csv('Broadband.csv')
data_mobile.to_csv('Mobile.csv')

from urllib.request import urlopen
import json
with urlopen('https://raw.githubusercontent.com/plotly/datasets/master/geojson-counties-fips.json') as response:
    countries = json.load(response)

import plotly.express as px

#fig = px.choropleth(data_broadband, geojson=countries)
#fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
#fig.show()

fig1  = px.choropleth(data_broadband, 
            locations='Country',
             color="Broadband Mbps",
            color_continuous_scale="Inferno",
              locationmode="country names",
               #scope="usa",
             range_color=(0,200),
             height=750)

fig1.update_layout(
    title="Global Broadband Speed Rank",
    legend_title="Broadband Speed (Mbps)",
    font=dict(
        #family="Courier New, monospace",
        #size=18,
        #color="RebeccaPurple"
    )
)

fig1.show()

fig2  = px.choropleth(data_mobile, 
            locations='Country',
             color="Mobile Mbps",
            color_continuous_scale="Inferno",
              locationmode="country names",
               #scope="usa",
             range_color=(0,140),
             title='Global Mobile Speed Rank',
             height=750)

fig2.show()
# Out:
# <div>                            <div id="99ba65c5-d482-4d94-9731-e2b15b35e9a7" class="plotly-graph-div" style="height:750px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("99ba65c5-d482-4d94-9731-e2b15b35e9a7")) {                    Plotly.newPlot(                        "99ba65c5-d482-4d94-9731-e2b15b35e9a7",                        [{"coloraxis":"coloraxis","geo":"geo","hovertemplate":"Country=%{location}<br>Broadband Mbps=%{z}<extra></extra>","locationmode":"country names","locations":["Monaco","Singapore","Chile","Thailand","Hong Kong (SAR)","Denmark","Macau (SAR)","China","United States","Spain","Romania","Liechtenstein","New Zealand","Japan","United Arab Emirates","Switzerland","Norway","Netherlands","Sweden","Hungary","Canada","Portugal","South Korea","Kuwait","Taiwan","Panama","France","Andorra","Moldova","Luxembourg","Malta","Finland","Israel","Brazil","Poland","Uruguay","Malaysia","Belgium","Lithuania","Trinidad and Tobago","Saudi Arabia","Saint Lucia","Qatar","Germany","Barbados","San Marino","Vietnam","Ireland","Latvia","Russia","Slovenia","United Kingdom","Colombia","Saint Vincent and the Grenadines","Bulgaria","Paraguay","Ukraine","Estonia","Austria","Dominica","Australia","Montenegro","Costa Rica","Grenada","Jordan","Italy","Philippines","Serbia","Czechia","Bahrain","Slovakia","India","Mongolia","Belarus","Kosovo","Kyrgyzstan","Peru","Oman","Nepal","Croatia","Mexico","Argentina","The Bahamas","Uzbekistan","Jamaica","Egypt","Brunei","Armenia","Ecuador","Kazakhstan","Albania","Greece","Belize","Bangladesh","C\u00f4te d'Ivoire","Guyana","South Africa","Cyprus","Nicaragua","Laos","Ghana","North Macedonia","Turkey","Hon